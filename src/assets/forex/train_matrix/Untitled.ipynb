# %%
import pandas as pd

# %%
df = pd.read_csv('test_df.csv')

# %%
df
# Out:
#                       Date               Date.1    Close  Volume
# 0      2010-01-03 19:39:00  2010-01-03 19:39:00  1.43064    93.0  \
# 1      2010-01-03 21:13:00  2010-01-03 21:13:00  1.42858   144.0
# 2      2010-01-04 00:44:00  2010-01-04 00:44:00  1.43046    63.0
# 3      2010-01-04 02:35:00  2010-01-04 02:35:00  1.42779   146.0
# 4      2010-01-04 03:39:00  2010-01-04 03:39:00  1.43190   115.0
# ...                    ...                  ...      ...     ...
# 88249  2024-01-03 15:09:00  2024-01-03 15:09:00  1.09196   182.0
# 88250  2024-01-03 16:25:00  2024-01-03 16:25:00  1.09220   107.0
# 88251  2024-01-03 19:30:00  2024-01-03 19:30:00  1.09250    77.0
# 88252  2024-01-03 21:19:00  2024-01-03 21:19:00  1.09175    53.0
# 88253  2024-01-03 23:30:00  2024-01-03 23:30:00  1.09255    73.0
#
#        Close_AUDUSD  Close_USDCAD  Close_USDCHF  AUDUSD_Returns
# 0           0.89676       1.04778       1.03557       -0.000210  \
# ...

# %%
df =df.dropna()

# %%
df
# Out:
#                       Date               Date.1    Close  Volume
# 20     2010-01-05 04:25:00  2010-01-05 04:25:00  1.44281    63.0  \
# 21     2010-01-05 05:47:00  2010-01-05 05:47:00  1.44255    52.0
# 22     2010-01-05 07:13:00  2010-01-05 07:13:00  1.44222    39.0
# 23     2010-01-05 08:30:00  2010-01-05 08:30:00  1.44332    67.0
# 24     2010-01-05 09:20:00  2010-01-05 09:20:00  1.44165   152.0
# ...                    ...                  ...      ...     ...
# 88174  2023-12-27 14:11:00  2023-12-27 14:11:00  1.10989   169.0
# 88175  2023-12-27 15:27:00  2023-12-27 15:27:00  1.11040    93.0
# 88176  2023-12-27 17:05:00  2023-12-27 17:05:00  1.11035    24.0
# 88179  2023-12-28 00:00:00  2023-12-28 00:00:00  1.11104   122.0
# 88201  2023-12-29 05:02:00  2023-12-29 05:02:00  1.10519   148.0
#
#        Close_AUDUSD  Close_USDCAD  Close_USDCHF  AUDUSD_Returns
# 20          0.91394       1.03742       1.02941        0.000028  \
# ...

# %%
count = df[df['label'] == -1.0]['label'].count()

# %%
count
# Out:
# 40046

# %%
count = df[df['label'] == 1.0]['label'].count()

# %%
count
# Out:
# 41135
