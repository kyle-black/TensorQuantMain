# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df =pd.read_csv('traded_df20.csv')

# %%
df
# Out:
#       Unnamed: 0.1  index  Unnamed: 0  label  Middle_Band  Upper_Band
# 0                0      0           0      1         1.06        1.06  \
# 1                1      1           1      1         1.06        1.06
# 2                2      2           2      1         1.06        1.06
# 3                3      3           3      1         1.06        1.06
# 4                4      4           4      1         1.06        1.06
# ...            ...    ...         ...    ...          ...         ...
# 1995          1995   1995        1995      0         1.07        1.08
# 1996          1996   1996        1996      0         1.07        1.08
# 1997          1997   1997        1997      0         1.07        1.08
# 1998          1998   1998        1998      0         1.07        1.08
# 1999          1999   1999        1999      0         1.07        1.08
#
#       Lower_Band  Log_Returns  MACD  Signal_Line_MACD  ...  Choice  Accurate
# 0           1.06         0.00 -0.00             -0.00  ...    1.00      True  \
# 1           1.06         0.00 -0.00             -0.00  ...    1.00      True
# 2           1.06        -0.00 -0.00             -0.00  ...    1.00      True
# 3           1.06        -0.00 -0.00             -0.00  ...    1.00      True
# 4           1.06         0.00 -0.00             -0.00  ...    1.00      True
# ...          ...          ...   ...               ...  ...     ...       ...
# 1995        1.07         0.00  0.00              0.00  ...    1.00     False
# 1996        1.07        -0.00  0.00              0.00  ...    1.00     False
# 1997        1.07         0.00  0.00              0.00  ...    1.00     False
# 1998        1.07         0.00  0.00              0.00  ...    1.00     False
# 1999        1.07         0.00  0.00              0.00  ...    1.00     False
#
#       major_proba  scaled_proba  adjusted_lot_size  pip_movement  pip_value
# 0            0.58          0.62            7047.11         52.00       0.66  \
# 1            0.62          0.91           10381.90         67.20       0.98
# 2            0.62          0.91           10366.41         56.30       0.98
# 3            0.62          0.89           10174.74         57.20       0.96
# 4            0.60          0.76            8692.49         65.20       0.82
# ...           ...           ...                ...           ...        ...
# 1995         0.54          0.32            3706.01        -72.90       0.34
# 1996         0.57          0.53            6000.69        -80.40       0.56
# 1997         0.55          0.38            4384.65        -62.20       0.41
# 1998         0.57          0.48            5484.12        -63.70       0.51
# 1999         0.57          0.52            5946.55        -66.70       0.55
#
#       net_dollar_value  Profit_Loss  account_balance
# 0                34.48        34.48          1030.00
# 1                65.75        65.75          1090.00
# 2                55.04        55.04          1142.00
# 3                54.89        54.89          1197.00
# 4                53.40        53.40          1253.00
# ...                ...          ...              ...
# 1995            -25.13       -25.13          1292.00
# 1996            -44.94       -44.94          1241.00
# 1997            -25.39       -25.39          1213.00
# 1998            -32.52       -32.52          1179.00
# 1999            -36.92       -36.92          1141.00
#
# [2000 rows x 47 columns]

# %%
acc_50 = df['Accurate'].mean()

# %%
acc_50
# Out:
# 0.5125

# %%
acc_51_df = df[df['major_proba'] > 0.51]

# %%
acc_51 = acc_51_df['Accurate'].mean()

# %%
acc_51
# Out:
# 0.5145844799119428

# %%
acc_52_df = df[df['major_proba'] > 0.52]

# %%
acc_52 = acc_52_df['Accurate'].mean()

# %%
acc_52
# Out:
# 0.5320197044334976

# %%
acc_53_df = df[df['major_proba'] > 0.53]

# %%
acc_53 = acc_53_df['Accurate'].mean()

# %%
acc_53
# Out:
# 0.5429553264604811

# %%
acc_54_df = df[df['major_proba'] > 0.54]

# %%
acc_54 = acc_54_df['Accurate'].mean()

# %%
acc_54
# Out:
# 0.5556426332288401

# %%
acc_55_df = df[df['major_proba'] > 0.55]

# %%
acc_55 = acc_55_df['Accurate'].mean()

# %%
acc_55
# Out:
# 0.5656192236598891

# %%
acc_56_df = df[df['major_proba'] > 0.56]

# %%
acc_56 = acc_56_df['Accurate'].mean()

# %%
acc_56
# Out:
# 0.586015538290788

# %%
acc_57_df = df[df['major_proba'] > 0.57]

# %%
acc_57 = acc_57_df['Accurate'].mean()

# %%
acc_57
# Out:
# 0.6151685393258427

# %%
acc_58_df = df[df['major_proba'] > 0.58]

# %%
acc_58 = acc_58_df['Accurate'].mean()

# %%
acc_58
# Out:
# 0.6351351351351351

# %%
acc_59_df = df[df['major_proba'] > 0.59]

# %%
acc_59 = acc_59_df['Accurate'].mean()

# %%
acc_59
# Out:
# 0.6388059701492538

# %%
acc_60_df = df[df['major_proba'] > 0.60]

# %%
acc_60 = acc_60_df['Accurate'].mean()

# %%
acc_60
# Out:
# 0.7258064516129032

# %%
proba_dict ={'0.50':acc_50,'0.51':acc_51,'0.52':acc_52, '0.53':acc_53,'0.54':acc_54, '0.55':acc_55, '0.56':acc_56, '0.57':acc_57, '0.58':acc_58, '0.59':acc_59, '0.60':acc_60}

# %%
proba_dict
# Out:
# {'0.50': 0.5125,
#  '0.51': 0.5145844799119428,
#  '0.52': 0.5320197044334976,
#  '0.53': 0.5429553264604811,
#  '0.54': 0.5556426332288401,
#  '0.55': 0.5656192236598891,
#  '0.56': 0.586015538290788,
#  '0.57': 0.6151685393258427,
#  '0.58': 0.6351351351351351,
#  '0.59': 0.6388059701492538,
#  '0.60': 0.7258064516129032}

# %%
oswald_font = 'Oswald'

# %%
plt.rcParams['font.family'] = 'monospace'  # Change font family (e.g., 'serif', 'sans-serif', 'monospace')
plt.rcParams['font.size'] = 12              # Set global font size
plt.rcParams['font.weight'] = 'bold'

# %%
x = list(proba_dict.keys())
y = list(proba_dict.values())

min_y = np.floor(min(y) * 100) / 100  # Get the minimum y value rounded down to hundredths
max_y = np.ceil(max(y) * 100) / 100

# %%
plt.plot(x, y, color='red', linestyle='-', linewidth=2, label='Connecting Line')
plt.scatter(x, y)



ticks = np.arange(min_y, max_y + 0.01, 0.01) 

plt.yticks(ticks, [f'{tick:.2f}' for tick in ticks]) 

# Add labels and title
plt.xlabel('Model Probability Threshold')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy at incremental probability thresholds')
ax = plt.gca()



# Show the plot
for tick in ax.get_yticks():
    tick_label = ax.yaxis.get_major_ticks()[list(ax.get_yticks()).index(tick)].label1
    if tick % 0.05 == 0:  # For ticks divisible by 0.05 (e.g., 0.50, 0.55, 0.60)
        tick_label.set_fontsize(8)
        tick_label.set_fontweight('bold')  # Make it bold
    else:
        tick_label.set_fontsize(10)  # Normal size for others

# Show the plot
plt.savefig('scatter_plot.png', transparent=True, dpi=300)
plt.show()

# %%
plt.savefig('scatter_plot.png', transparent=False, dpi=300)
