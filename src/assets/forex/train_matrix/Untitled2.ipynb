# %%
import pandas as pd

# %%
! pip install pyarrow fastparquet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.3 MB/s eta 0:00:00m eta 0:00:01:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.7 MB/s eta 0:00:0031m39.2 MB/s eta 0:00:01
# ...

# %%
df =pd.read_parquet('barrier_check.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df =pd.read_parquet('barrier_check.parquet')
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     428 @doc(storage_options=_shared_docs["storage_options"])
#     429 def read_parquet(
#     430     path: FilePath | ReadBuffer[bytes],
#    (...)
#     436     **kwargs,
#     437 ) -> DataFrame:
#     438     """
#     439     Load a parquet object from the file path, returning a DataFrame.
#     440
#    (...)
#     491     DataFrame
#     492     """
# --> 493     impl = get_engine(engine)
#     495     if use_nullable_dtypes is not lib.no_default:
#     496         msg = (
#     497             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
# ...
